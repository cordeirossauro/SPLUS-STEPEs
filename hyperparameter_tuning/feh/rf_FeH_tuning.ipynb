# %%
# Import list
import numpy as np
import pandas as pd
import os
import time
import itertools

os.chdir('../..')
import AstroPack as AP
os.chdir('./hyperparameter_tuning/feh')

from matplotlib import rc
rc('text', usetex=True)

from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# # Getting the data

# %%
# Create a list with all the columns that will be used
column_list = ['ID', 'teff', 'teff_err', 'logg', 'logg_err', 'feh', 'feh_err'] + AP.Filters['JPLUS'] + AP.Filters['WISE'] + AP.Filters['GAIA']

# Import the full dataframe with stars that have both SPLUS, WISE, GAIA and LAMOST data
os.chdir('../../data')
stars_raw = pd.read_csv('STEPPs Input Data (SPLUS) - Corrected.csv', usecols=column_list)
os.chdir('../hyperparameter_tuning/feh')

# The DataFrame assembler from AstroPack takes a 'TILE_ID' and a 'NUMBER' for each star (inherited from the J-PLUS tables), 
# and since the S-PLUS stars don't have those, we create dummy ones
stars_raw['TILE_ID'] = np.arange(len(stars_raw))
stars_raw['NUMBER'] = 1

# Drop any row with missing values from the dataframe
stars_raw = stars_raw.dropna()

# Filter the stars according to their parameter errors
stars_raw = stars_raw[stars_raw['teff_err'] <= 300]
stars_raw = stars_raw[stars_raw['logg_err'] <= 0.4]
stars_raw = stars_raw[stars_raw['feh_err'] <= 0.4]

# %%
# Convert it into a dataframe with magnitudes and colors, indexed by the TILE ID and NUMBER of the star
stars_raw, stars = AP.AssembleWorkingDF(stars_raw, addWISE=True, addGALEX=False, addGAIA=True, Colors=True, Combinations=False)

# Get the metalicities
feh = stars_raw['feh']

# %% [markdown]
# # Random Forest CV - FeH

# %%
# Split the full sample into training and test samples
x_develop, x_test, y_develop, y_test = train_test_split(stars, feh, test_size=0.25, random_state=42)

# %%
# Create lists with the values of each hyperparameter that will be tested
n_features = [15]
n_trees = [50, 100]
min_samples_leaf = [1, 10]
max_features = [0.25, 0.5, 0.75, 'auto']
criterion = ["mse"]

# Create a list containing every possible combination of hyperparameters
HPCombinations = [item for item in itertools.product(n_features, n_trees, min_samples_leaf, max_features, criterion)]

# %%
# Loop through all the hyperparameter combinations
for HPCombination in HPCombinations:
    # By doing a 4-fold, 2-repeat cross-validation, calculate the average value and the standard deviation of the error metrics 
    # and elapsed time for a model initizalized with the hyperparameter combination
    Metrics = AP.rf_evaluator(HPCombination, x_develop, y_develop, n_splits = 4, n_repeats = 2, verbose = 1)
    
    # Save the hyperparameter combination and the evaluation results to a csv file
    pd.DataFrame(data=(HPCombination + Metrics)).T.to_csv('rf_FeH_tuning.csv', mode='a', index = False, header = False)
# Out:
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 1 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.122 (0.002)
# Root Mean Squared Error: 0.165  (0.002)
# Max Error: 1.373 (0.183)
# R2 Score: 0.814 (0.007)
# Time Elapsed: 21.369 (1.521) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 1 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.121 (0.001)
# Root Mean Squared Error: 0.165  (0.003)
# Max Error: 1.347 (0.139)
# R2 Score: 0.815 (0.008)
# Time Elapsed: 24.720 (3.526) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 1 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.121 (0.002)
# Root Mean Squared Error: 0.165  (0.003)
# Max Error: 1.337 (0.185)
# R2 Score: 0.815 (0.005)
# Time Elapsed: 28.295 (6.713) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 1 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.122 (0.001)
# Root Mean Squared Error: 0.166  (0.002)
# Max Error: 1.346 (0.225)
# R2 Score: 0.813 (0.009)
# Time Elapsed: 27.363 (0.463) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 10 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.124 (0.001)
# Root Mean Squared Error: 0.169  (0.001)
# Max Error: 1.479 (0.152)
# R2 Score: 0.807 (0.006)
# Time Elapsed: 19.399 (0.831) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 10 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.122 (0.001)
# Root Mean Squared Error: 0.166  (0.003)
# Max Error: 1.404 (0.202)
# R2 Score: 0.812 (0.004)
# Time Elapsed: 27.948 (6.468) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 10 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.122 (0.002)
# Root Mean Squared Error: 0.167  (0.004)
# Max Error: 1.469 (0.166)
# R2 Score: 0.810 (0.008)
# Time Elapsed: 21.608 (0.474) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 10 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.123 (0.001)
# Root Mean Squared Error: 0.169  (0.002)
# Max Error: 1.507 (0.205)
# R2 Score: 0.807 (0.004)
# Time Elapsed: 25.573 (4.372) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 1 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.121 (0.001)
# Root Mean Squared Error: 0.164  (0.002)
# Max Error: 1.396 (0.185)
# R2 Score: 0.818 (0.004)
# Time Elapsed: 22.806 (3.110) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 1 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.120 (0.001)
# Root Mean Squared Error: 0.162  (0.003)
# Max Error: 1.287 (0.216)
# R2 Score: 0.821 (0.007)
# Time Elapsed: 26.236 (1.052) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 1 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.120 (0.002)
# Root Mean Squared Error: 0.164  (0.003)
# Max Error: 1.338 (0.196)
# R2 Score: 0.818 (0.009)
# Time Elapsed: 37.792 (8.964) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 1 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.121 (0.001)
# Root Mean Squared Error: 0.165  (0.003)
# Max Error: 1.407 (0.187)
# R2 Score: 0.815 (0.006)
# Time Elapsed: 42.650 (3.702) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 10 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.123 (0.001)
# Root Mean Squared Error: 0.168  (0.002)
# Max Error: 1.430 (0.095)
# R2 Score: 0.808 (0.004)
# Time Elapsed: 23.187 (4.583) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 10 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.122 (0.002)
# Root Mean Squared Error: 0.166  (0.003)
# Max Error: 1.489 (0.189)
# R2 Score: 0.813 (0.008)
# Time Elapsed: 32.762 (5.551) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 10 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.122 (0.001)
# Root Mean Squared Error: 0.166  (0.002)
# Max Error: 1.530 (0.196)
# R2 Score: 0.813 (0.005)
# Time Elapsed: 29.969 (3.905) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 10 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 0.122 (0.001)
# Root Mean Squared Error: 0.168  (0.002)
# Max Error: 1.456 (0.264)
# R2 Score: 0.809 (0.005)
# Time Elapsed: 36.941 (8.929) s

# %% [markdown]
# # Graphical Analysis

# %%
hp_tuning_rf = pd.read_csv('rf_FeH_tuning.csv')

x_axis = {'max_features': ['0.25', '0.5', '0.75', 'auto']}
y_axis = {'n_features': [190, 60, 45, 15]}

# %%
t_50_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 1}, x_axis, y_axis, 'R2')
t_100_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 1}, x_axis, y_axis, 'R2')
t_50_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 10}, x_axis, y_axis, 'R2')
t_100_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 10}, x_axis, y_axis, 'R2')

# %%
figure = AP.plot_heatmaps(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',  
                          t_50_l_10_matrix, r'\textbf{n\_trees = 50, msl = 10}',
                          t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                          t_100_l_10_matrix, r'\textbf{n\_trees = 100, msl = 10}', 
                          x_label = 'max\_features', y_label = 'n\_features',
                          value_format = '.3f', cmap = 'Greens', v_min = 0.805, v_max = 0.835, 
                          colorbar_label='R2', colorbar_ticks = 6)

figure.savefig('rf_FeH_R2_heatmap.jpg', dpi = 250)

# %%
figure = AP.plot_heatmaps_single_line(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',
                                      t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                                      x_label = 'max\_features', y_label = 'n\_features',
                                      value_format = '.3f', cmap = 'Greens', v_min = 0.805, v_max = 0.835, 
                                      colorbar_label='R2', colorbar_ticks = 6)

figure.savefig('rf_FeH_R2_heatmap (msl = 1).jpg', dpi = 250)

# %%
t_50_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 1}, x_axis, y_axis, 'Time').astype(int)
t_100_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 1}, x_axis, y_axis, 'Time').astype(int)
t_50_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 10}, x_axis, y_axis, 'Time').astype(int)
t_100_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 10}, x_axis, y_axis, 'Time').astype(int)

# %%
figure = AP.plot_heatmaps(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',  
                          t_50_l_10_matrix, r'\textbf{n\_trees = 50, msl = 10}',
                          t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                          t_100_l_10_matrix, r'\textbf{n\_trees = 100, msl = 10}', 
                          x_label = 'max\_features', y_label = 'n\_features',
                          value_format = 'd', cmap = 'Greens', v_min = 15, v_max = 200, 
                          colorbar_label='time(s)', colorbar_ticks = 6)

figure.savefig('rf_FeH_time_heatmap.jpg', dpi = 250)

# %%
figure = AP.plot_heatmaps_single_line(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',
                                      t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}', 
                                      value_format = 'd', cmap = 'Greens', v_min = 15, v_max = 200, 
                                      x_label = 'max\_features', y_label = 'n\_features',
                                      colorbar_label='time(s)', colorbar_ticks = 6)

figure.savefig('rf_FeH_time_heatmap (msl = 1).jpg', dpi = 250)
