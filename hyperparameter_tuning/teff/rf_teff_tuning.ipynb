# %%
# Import list
import numpy as np
import pandas as pd
import os
import time
import itertools

os.chdir('../..')
import AstroPack as AP
os.chdir('./hyperparameter_tuning/teff')

from matplotlib import rc
rc('text', usetex=True)

from sklearn.model_selection import train_test_split

# %matplotlib inline

# %% [markdown]
# # Getting the data

# %%
# Create a list of the columns that will be used
column_list = ['ID', 'teff', 'teff_err', 'logg', 'logg_err', 'feh', 'feh_err'] + AP.Filters['JPLUS'] + AP.Filters['WISE'] + AP.Filters['GAIA']

# Import the full dataframe with stars that have both SPLUS, WISE, GAIA and LAMOST data
os.chdir('../../data')
stars_raw = pd.read_csv('STEPPs Input Data (SPLUS) - Corrected.csv', usecols=column_list)
os.chdir('../hyperparameter_tuning/teff')

stars_raw['TILE_ID'] = np.arange(len(stars_raw))
stars_raw['NUMBER'] = 1

# Drop any row with missing values from the dataframe
stars_raw = stars_raw.dropna()

# Filter the stars according to their parameter errors
stars_raw = stars_raw[stars_raw['teff_err'] <= 300]
stars_raw = stars_raw[stars_raw['logg_err'] <= 0.4]
stars_raw = stars_raw[stars_raw['feh_err'] <= 0.4]

# %%
# Convert it into a dataframe with magnitudes and colors, indexed by the TILE ID and NUMBER of the star
stars_raw, stars = AP.AssembleWorkingDF(stars_raw, addWISE=True, addGALEX=False, addGAIA=True, Colors=True, Combinations=False)

# Get the effective temperature
teff = stars_raw['teff']

# %% [markdown]
# # Random Forest CV - Teff

# %%
# Split the full sample into training and test samples
x_develop, x_test, y_develop, y_test = train_test_split(stars, teff, test_size=0.25, random_state=42)

# %%
# Create lists with the values of each hyperparameter that will be testedn_features = [10, 45, 60, 190]
n_features = [15]
n_trees = [50, 100]
min_samples_leaf = [1, 10]
max_features = [0.25, 0.5, 0.75, 'auto']
criterion = ["mse"]

# Create a list containing every possible combination of hyperparameters
HPCombinations = [item for item in itertools.product(n_features, n_trees, min_samples_leaf, max_features, criterion)]

# %%
# Loop through all the hyperparameter combinations
for HPCombination in HPCombinations:
    # By doing a 4-fold, 2-repeat cross-validation, calculate the average value and the standard deviation of the error metrics 
    # and elapsed time for a model initizalized with the hyperparameter combination    
    Metrics = AP.rf_evaluator(HPCombination, x_develop, y_develop, n_splits = 4, n_repeats = 2, verbose = 1)
    
    # Save the hyperparameter combination and the evaluation results to a csv file    
    pd.DataFrame(data=(HPCombination + Metrics)).T.to_csv('rf_teff_tuning.csv', mode='a', index = False, header = False)
# Out:
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 1 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.311 (0.706)
# Root Mean Squared Error: 93.973  (1.805)
# Max Error: 1235.826 (140.801)
# R2 Score: 0.971 (0.001)
# Time Elapsed: 22.919 (0.684) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 1 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.170 (0.714)
# Root Mean Squared Error: 93.778  (1.076)
# Max Error: 1227.224 (120.332)
# R2 Score: 0.971 (0.001)
# Time Elapsed: 31.875 (6.272) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 1 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.088 (1.021)
# Root Mean Squared Error: 93.818  (2.615)
# Max Error: 1148.301 (213.221)
# R2 Score: 0.971 (0.002)
# Time Elapsed: 31.871 (7.538) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 1 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.895 (0.395)
# Root Mean Squared Error: 93.406  (1.659)
# Max Error: 1167.517 (160.778)
# R2 Score: 0.971 (0.001)
# Time Elapsed: 36.269 (6.243) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 10 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.172 (0.755)
# Root Mean Squared Error: 93.825  (2.843)
# Max Error: 1069.478 (242.608)
# R2 Score: 0.971 (0.002)
# Time Elapsed: 26.429 (2.299) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 10 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.690 (0.676)
# Root Mean Squared Error: 93.272  (1.230)
# Max Error: 1236.570 (97.282)
# R2 Score: 0.972 (0.001)
# Time Elapsed: 24.750 (3.201) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 10 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.919 (0.597)
# Root Mean Squared Error: 93.834  (0.868)
# Max Error: 1239.502 (145.519)
# R2 Score: 0.971 (0.001)
# Time Elapsed: 24.802 (3.293) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 50, min_samples_leaf = 10 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.996 (0.573)
# Root Mean Squared Error: 93.840  (2.199)
# Max Error: 1151.195 (253.416)
# R2 Score: 0.971 (0.002)
# Time Elapsed: 24.582 (0.233) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 1 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.921 (0.781)
# Root Mean Squared Error: 93.542  (1.893)
# Max Error: 1154.111 (214.954)
# R2 Score: 0.971 (0.002)
# Time Elapsed: 22.414 (0.190) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 1 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.728 (0.498)
# Root Mean Squared Error: 93.211  (1.529)
# Max Error: 1213.029 (135.919)
# R2 Score: 0.972 (0.001)
# Time Elapsed: 26.744 (0.201) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 1 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.630 (0.947)
# Root Mean Squared Error: 93.296  (1.443)
# Max Error: 1250.707 (151.052)
# R2 Score: 0.971 (0.001)
# Time Elapsed: 30.847 (0.164) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 1 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.555 (0.452)
# Root Mean Squared Error: 93.069  (1.517)
# Max Error: 1180.973 (129.113)
# R2 Score: 0.972 (0.001)
# Time Elapsed: 35.175 (0.307) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 10 , max_features = 0.25, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 67.201 (0.712)
# Root Mean Squared Error: 93.928  (3.188)
# Max Error: 1087.258 (225.534)
# R2 Score: 0.971 (0.002)
# Time Elapsed: 21.156 (0.177) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 10 , max_features = 0.5, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.697 (0.446)
# Root Mean Squared Error: 93.505  (2.390)
# Max Error: 1200.082 (176.214)
# R2 Score: 0.971 (0.002)
# Time Elapsed: 24.352 (0.162) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 10 , max_features = 0.75, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.765 (0.765)
# Root Mean Squared Error: 93.516  (1.786)
# Max Error: 1191.239 (197.475)
# R2 Score: 0.971 (0.001)
# Time Elapsed: 29.630 (4.319) s
#
#
# Starting Random Forest 4-Fold, 2 repeat CV with: n_features = 15, n_trees = 100, min_samples_leaf = 10 , max_features = auto, criterion = mse...
# Current Fold: 1/8
# Current Fold: 2/8
# Current Fold: 3/8
# Current Fold: 4/8
# Current Fold: 5/8
# Current Fold: 6/8
# Current Fold: 7/8
# Current Fold: 8/8
# CV Process Finished! Results:
# Mean Absolute Error: 66.781 (0.652)
# Root Mean Squared Error: 93.631  (1.716)
# Max Error: 1250.559 (142.968)
# R2 Score: 0.971 (0.001)
# Time Elapsed: 37.451 (1.074) s

# %% [markdown]
# # Graphical Analysis

# %%
hp_tuning_rf = pd.read_csv('rf_teff_tuning.csv')

x_axis = {'max_features': ['0.25', '0.5', '0.75', 'auto']}
y_axis = {'n_features': [190, 60, 45, 15]}

# %%
t_50_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 1}, x_axis, y_axis, 'R2')
t_100_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 1}, x_axis, y_axis, 'R2')
t_50_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 10}, x_axis, y_axis, 'R2')
t_100_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 10}, x_axis, y_axis, 'R2')

# %%
figure = AP.plot_heatmaps(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',  
                          t_50_l_10_matrix, r'\textbf{n\_trees = 50, msl = 10}',
                          t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                          t_100_l_10_matrix, r'\textbf{n\_trees = 100, msl = 10}', 
                          x_label = 'max\_features', y_label = 'n\_features',
                          value_format = '.3f', cmap = 'Reds', v_min = 0.970, v_max = 0.974, 
                          colorbar_label='R2', colorbar_ticks = 5)

figure.savefig('rf_teff_R2_heatmap.jpg', dpi = 250)

# %%
figure = AP.plot_heatmaps_single_line(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',
                                      t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                                      x_label = 'max\_features', y_label = 'n\_features',
                                      value_format = '.3f', cmap = 'Reds', v_min = 0.970, v_max = 0.974, 
                                      colorbar_label='R2', colorbar_ticks = 5)

figure.savefig('rf_teff_R2_heatmap (msl = 1)).jpg', dpi = 250)

# %%
t_50_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 1}, x_axis, y_axis, 'Time').astype(int)
t_100_l_1_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 1}, x_axis, y_axis, 'Time').astype(int)
t_50_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 50, 'min_samples_leaf': 10}, x_axis, y_axis, 'Time').astype(int)
t_100_l_10_matrix = AP.create_heatmap_matrix(hp_tuning_rf, {'n_trees': 100, 'min_samples_leaf': 10}, x_axis, y_axis, 'Time').astype(int)

# %%
figure = AP.plot_heatmaps(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',  
                          t_50_l_10_matrix, r'\textbf{n\_trees = 50, msl = 10}',
                          t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                          t_100_l_10_matrix, r'\textbf{n\_trees = 100, msl = 10}', 
                          x_label = 'max\_features', y_label = 'n\_features',
                          value_format = 'd', cmap = 'Reds', v_min = 15, v_max = 235, 
                          colorbar_label='time (s)', colorbar_ticks = 6)

figure.savefig('rf_teff_time_heatmap.jpg', dpi = 250)

# %%
figure = AP.plot_heatmaps_single_line(t_50_l_1_matrix, r'\textbf{n\_trees = 50, msl = 1}',  
                                      t_100_l_1_matrix, r'\textbf{n\_trees = 100, msl = 1}',
                                      x_label = 'max\_features', y_label = 'n\_features',
                                      value_format = 'd', cmap = 'Reds', v_min = 15, v_max = 235, 
                                      colorbar_label='time (s)', colorbar_ticks = 6)

figure.savefig('rf_teff_time_heatmap (msl = 1).jpg', dpi = 250)
